# %%
import matplotlib.pyplot as plt

x=[1,2,3,4]
y=[12,23,43,54]

plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4]
y=[10,20,40,50]

plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt

x=[0]
y=[0]

plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4,5]
y=[10,20,30,40,50]

plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4]
y=[30,12]

plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4]
y=[30,30,30,30]

plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt

x=['mon', 'tues', 'wed', 'thu', 'fri']
y=[1,15,2,9,37]
plt.plot(x,y)
plt.title('sales')
plt.xlabel('days of the weeks')
plt.ylabel('sales ofb the day')

plt.show()

# %%
import matplotlib.pyplot as plt

x = ['mon', 'tues', 'wed', 'thus', 'fri', 'sat', 'sun']
y = [54, 20, 74, 40, 25, 95, 12]

plt.plot(x,y)
plt.title("sales data weekly")
plt.xlabel("days")
plt.ylabel("sales")
plt.show()
